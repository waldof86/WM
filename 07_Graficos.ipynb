# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('06_Analisis.xlsx')
df.drop(columns=['Unnamed: 0','indice','link','contenido','copete','oraciones','eval','estrellas_totales'], inplace=True)
df['label_final'] = df['label_final'].astype('category')
df['Diario'] = df['Diario'].astype('category')

# %%
df.head(10)
# Out:
#                                               titulo               fecha  \
# 0       "Más sumisión geopolítica que afán de venta" 2024-04-07 01:49:43
# 1  Tristán Bauer: "Usan fake news como cortinas d... 2024-04-07 02:06:34
# 2  Crecen las opiniones negativas y hay poca paci... 2024-04-07 01:08:41
# 3                            Milei, el conferencista 2024-04-07 00:21:26
# 4  "Va a llevar tiempo restaurar lo que destruya ... 2024-04-07 02:28:29
# 5  Cristina Kirchner cuestionó la política económ... 2024-04-06 21:22:55
# 6  Mónica Cabrera, "Mondo Roto", y el humor polít... 2024-04-06 21:21:33
# 7                          El marketing de la crisis 2024-04-06 21:04:48
# 8                     Unidos por la fe y el Ejército 2024-04-06 19:30:09
# 9  Denuncia internacional contra Luis Petri por o... 2024-04-06 19:14:25
#
#      Diario  orac_totales  orac_validas  estrellas_neto  eval_final  \
# 0  Pagina12            11             2            -4.0   -2.000000
# ...

# %%
df.dtypes
# Out:
# titulo                    object
# fecha             datetime64[ns]
# Diario                  category
# orac_totales               int64
# orac_validas               int64
# estrellas_neto           float64
# eval_final               float64
# label_final             category
# dtype: object

# %%
# df['yearmonth'] = df['fecha'].dt.strftime('%m')

# # Create a count plot using Seaborn
# plt.figure(figsize=(10, 6))
# sns.countplot(x='yearmonth', hue='label_final', data=df)
# plt.title('Count of Rows per Category over Weeks')
# plt.xlabel('Week')
# plt.ylabel('Count')
# plt.legend(title='Category')
# plt.show()

# %%
sns.set_theme()
